# %% [markdown]
# # 1.2 Correlation Analysis

# %% [markdown]
# ### Q1.2.1 Compute the correlation matrix of all features.

# %%
import pandas as pd
df = pd.read_csv("/Users/theodorsjetnanutvik/Desktop/MaskinLæring/assignment1/data/WineQT.csv")

# Compute correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Show correlations with quality
corr_matrix["quality"].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.484866
# sulphates               0.257710
# citric acid             0.240821
# fixed acidity           0.121970
# Id                      0.069708
# residual sugar          0.022002
# pH                     -0.052453
# free sulfur dioxide    -0.063260
# chlorides              -0.124085
# density                -0.175208
# total sulfur dioxide   -0.183339
# volatile acidity       -0.407394
# Name: quality, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ### 1.2.2 Plot a heatmap of the correlation matrix.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Matrix (Wine Dataset)")
plt.savefig("../results/corr_heatmap.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### 1.2.3 Which variable has the strongest positive correlation with quality? Which variable has the strongest negative correlation with quality?
#
# Reading from the correlation matrix we can find that:
# - The strongest positive correlation with **quality** is **alcohol**
#     $0.484866$
# - The strongest negative correlation with **quality** is **volatile acidity**
#     $-0.407394$
#
# ---

# %% [markdown]
# ### 1.2.4 Between alcohol and pH, which do you expect to better predict wine quality? Justify your answer.
#
# Alcohol shows a moderate positive correlation with wine quality (0.48), while pH is almost uncorrelated (–0.05). This suggests that alcohol is a much better predictor of quality. This result is consistent with domain intuition: alcohol content varies more across wines and is linked to perceived body and richness, whereas pH values cluster tightly and do not explain quality differences.
