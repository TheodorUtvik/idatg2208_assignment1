# %% [markdown]
# # 1.1 Exploration

# %% [markdown]
# ### Q 1.1.1 Load the dataset into a DataFrame and display the first 5 rows. Print the dataset information and summary statistics.

# %%
import pandas as pd

# Load CSV with comma separator
df = pd.read_csv("/Users/theodorsjetnanutvik/Desktop/MaskinLæring/assignment1/data/WineQT.csv")

print(df.head())
print(df.info())
print(df.describe())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %% [markdown]
# ## Answer 1.1.1
#
# Load the dataset into a DataFrame and display the first 5 rows. Print the dataset
# information and summary statistics.
#
# Loaded the dataset `WineQT.csv` into a Pandas DataFrame. The dataset consists of 1143 entries and 13 columns.
#
# ---

# %% [markdown]
# ### Q 1.1.2 Which features show the highest variation based on summary statistics?

# %%
# Calculate coefficient of variation (std / mean) for each feature
variation = (df.std() / df.mean()).sort_values(ascending=False)

print("Coefficient of Variation (sorted):")
print(variation)

# Optional: bar plot
import matplotlib.pyplot as plt

variation.drop("Id", errors="ignore").plot(kind="bar", figsize=(10,5))
plt.ylabel("Coefficient of Variation (std / mean)")
plt.title("Relative Variation of Features")
plt.tight_layout()
plt.show()
# Out:
# Coefficient of Variation (sorted):
# citric acid             0.732907
# total sulfur dioxide    0.713979
# free sulfur dioxide     0.656431
# Id                      0.576416
# chlorides               0.543724
# residual sugar          0.535480
# volatile acidity        0.338077
# sulphates               0.259080
# fixed acidity           0.210272
# quality                 0.142446
# alcohol                 0.103638
# pH                      0.047316
# density                 0.001931
# dtype: float64

# %% [markdown]
# Reviewing the numbers after finding the **Coefficient of Variation**, the features that show the highest variations are:
#
# - item Citric acid
# - item Total sulfur dioxide
# - item Free sulfur dioxide
